# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/covid19-tracking-germany/de_state.shp
# /kaggle/input/covid19-tracking-germany/de_county.prj
# /kaggle/input/covid19-tracking-germany/de_state.dbf
# /kaggle/input/covid19-tracking-germany/de_state.cpg
# /kaggle/input/covid19-tracking-germany/covid_de.csv
# /kaggle/input/covid19-tracking-germany/de_county.cpg
# /kaggle/input/covid19-tracking-germany/de_state.shx
# /kaggle/input/covid19-tracking-germany/demographics_de.csv
# /kaggle/input/covid19-tracking-germany/de_county.dbf
# /kaggle/input/covid19-tracking-germany/de_county.shx
# /kaggle/input/covid19-tracking-germany/de_state.prj
# /kaggle/input/covid19-tracking-germany/de_county.shp

# %%
covid = pd.read_csv('/kaggle/input/covid19-tracking-germany/covid_de.csv')
covid.head()
# Out:
#                 state              county age_group gender        date  cases  \
# 0  Baden-Wuerttemberg  LK Alb-Donau-Kreis     00-04      F  2020-03-27      1
# 1  Baden-Wuerttemberg  LK Alb-Donau-Kreis     00-04      F  2020-03-28      1
# 2  Baden-Wuerttemberg  LK Alb-Donau-Kreis     00-04      F  2020-04-03      1
# 3  Baden-Wuerttemberg  LK Alb-Donau-Kreis     00-04      F  2020-10-18      1
# 4  Baden-Wuerttemberg  LK Alb-Donau-Kreis     00-04      F  2020-10-22      1
#
#    deaths  recovered
# 0       0          1
# 1       0          1
# 2       0          1
# 3       0          1
# 4       0          1

# %%
covid['date'] = pd.to_datetime(covid['date'], format = '%Y-%m-%d')
covid.head()
# Out:
#                 state              county age_group gender       date  cases  \
# 0  Baden-Wuerttemberg  LK Alb-Donau-Kreis     00-04      F 2020-03-27      1
# 1  Baden-Wuerttemberg  LK Alb-Donau-Kreis     00-04      F 2020-03-28      1
# 2  Baden-Wuerttemberg  LK Alb-Donau-Kreis     00-04      F 2020-04-03      1
# 3  Baden-Wuerttemberg  LK Alb-Donau-Kreis     00-04      F 2020-10-18      1
# 4  Baden-Wuerttemberg  LK Alb-Donau-Kreis     00-04      F 2020-10-22      1
#
#    deaths  recovered
# 0       0          1
# 1       0          1
# 2       0          1
# 3       0          1
# 4       0          1

# %%
covid_bw = covid[covid['state'] == 'Baden-Wuerttemberg']
covid_bw.groupby('county')['cases'].count().reset_index()
# Out:
#                          county  cases
# 0            LK Alb-Donau-Kreis   1269
# 1                   LK Biberach   1110
# 2              LK Bodenseekreis    979
# 3                 LK Boeblingen   1657
# 4   LK Breisgau-Hochschwarzwald   1379
# 5                       LK Calw   1173
# 6                LK Emmendingen   1109
# 7                   LK Enzkreis   1294
# 8                  LK Esslingen   1973
# 9               LK Freudenstadt    965
# 10                LK Goeppingen   1569
# 11                LK Heidenheim    976
# 12                 LK Heilbronn   1584
# 13            LK Hohenlohekreis    926
# 14                 LK Karlsruhe   1565
# 15                  LK Konstanz   1181
# 16                  LK Loerrach   1257
# 17               LK Ludwigsburg   1889
# 18         LK Main-Tauber-Kreis    972
# 19     LK Neckar-Odenwald-Kreis    994
# 20              LK Ortenaukreis   1659
# 21               LK Ostalbkreis   1518
# 22                   LK Rastatt   1179
# 23                LK Ravensburg   1183
# 24           LK Rems-Murr-Kreis   1820
# 25                LK Reutlingen   1585
# 26        LK Rhein-Neckar-Kreis   1745
# 27                  LK Rottweil   1028
# 28          LK Schwaebisch Hall   1229
# 29    LK Schwarzwald-Baar-Kreis   1205
# 30               LK Sigmaringen    877
# 31                 LK Tuebingen   1368
# 32                LK Tuttlingen   1016
# 33                  LK Waldshut   1055
# 34           LK Zollernalbkreis   1283
# 35               SK Baden-Baden    649
# 36       SK Freiburg i.Breisgau   1243
# 37                SK Heidelberg   1066
# 38                 SK Heilbronn   1190
# 39                 SK Karlsruhe   1232
# 40                  SK Mannheim   1609
# 41                 SK Pforzheim   1186
# 42                 SK Stuttgart   2018
# 43                       SK Ulm   1077

# %%
covid_hd = covid[covid['county'] == 'SK Heidelberg']
covid_hd.groupby('age_group')['cases'].sum()
# Out:
# age_group
# 00-04      83
# 05-14     202
# 15-34    1300
# 35-59    1012
# 60-79     333
# 80-99     177
# Name: cases, dtype: int64

# %%
covid_hd.head()
# Out:
#                     state         county age_group gender       date  cases  \
# 47463  Baden-Wuerttemberg  SK Heidelberg     00-04      F 2020-08-05      2
# 47464  Baden-Wuerttemberg  SK Heidelberg     00-04      F 2020-08-16      1
# 47465  Baden-Wuerttemberg  SK Heidelberg     00-04      F 2020-08-22      1
# 47466  Baden-Wuerttemberg  SK Heidelberg     00-04      F 2020-09-01      1
# 47467  Baden-Wuerttemberg  SK Heidelberg     00-04      F 2020-09-03      2
#
#        deaths  recovered
# 47463       0          2
# 47464       0          1
# 47465       0          1
# 47466       0          1
# 47467       0          2

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
covid_hd_cases = covid_hd.groupby('date')['cases'].sum().reset_index()
covid_hd_cases
# Out:
#           date  cases
# 0   2020-03-04      2
# 1   2020-03-06      2
# 2   2020-03-09      1
# 3   2020-03-11      2
# 4   2020-03-12      2
# ..         ...    ...
# 213 2021-01-01     36
# 214 2021-01-02     11
# 215 2021-01-03     16
# 216 2021-01-04     21
# 217 2021-01-05     22
#
# [218 rows x 2 columns]

# %%
covid_hd_deaths = covid_hd.groupby('date')['deaths'].sum().reset_index()
covid_hd_deaths
# Out:
#           date  deaths
# 0   2020-03-04       0
# 1   2020-03-06       0
# 2   2020-03-09       0
# 3   2020-03-11       0
# 4   2020-03-12       0
# ..         ...     ...
# 213 2021-01-01       0
# 214 2021-01-02       0
# 215 2021-01-03       0
# 216 2021-01-04       0
# 217 2021-01-05       0
#
# [218 rows x 2 columns]

# %%
plt.figure(figsize=(16,10))
sns.set_style('ticks')
sns.set_context("poster")
ax = sns.lineplot(data=covid_hd_cases, x='date', y='cases', ci=None)
ax = sns.lineplot(data=covid_hd_deaths, x='date', y='deaths', ci=None)
plt.xticks(rotation=45, horizontalalignment='right')
plt.ylabel('cases')
plt.title('COVID-19 casis and deaths in Heidelberg, Germany')
sns.despine()
plt.show()

# %%
covid_hd_by_age = covid_hd.groupby(['age_group', 'gender'])['cases'].sum().reset_index()
covid_hd_by_age['gender'] = covid_hd_by_age['gender'].replace(['F'],'Female').replace(['M'],'Male')
covid_hd_by_age
# Out:
#    age_group  gender  cases
# 0      00-04  Female     39
# 1      00-04    Male     42
# 2      05-14  Female     94
# 3      05-14    Male    108
# 4      15-34  Female    661
# 5      15-34    Male    631
# 6      35-59  Female    509
# 7      35-59    Male    499
# 8      60-79  Female    167
# 9      60-79    Male    166
# 10     80-99  Female    118
# 11     80-99    Male     58

# %%
plt.figure(figsize=(16,10))
sns.set_style('ticks')
#sns.set_context("poster")
ax = sns.barplot(data=covid_hd_by_age, x='age_group', y='cases', hue='gender')
plt.title('COVID-19 cases by age and gender in Heidelberg, Germany')
sns.despine()
plt.show()

# %%
covid_hd_death_by_age = covid_hd.groupby(['age_group', 'gender'])['deaths'].sum().reset_index()
covid_hd_death_by_age['gender'] = covid_hd_by_age['gender'].replace(['F'],'Female').replace(['M'],'Male')
covid_hd_death_by_age
# Out:
#    age_group  gender  deaths
# 0      00-04  Female       0
# 1      00-04    Male       0
# 2      05-14  Female       0
# 3      05-14    Male       0
# 4      15-34  Female       0
# 5      15-34    Male       0
# 6      35-59  Female       1
# 7      35-59    Male       2
# 8      60-79  Female       1
# 9      60-79    Male       9
# 10     80-99  Female      16
# 11     80-99    Male       9

# %%
plt.figure(figsize=(16,10))
sns.set_style('ticks')
#sns.set_context("poster")
ax = sns.barplot(data=covid_hd_death_by_age, x='age_group', y='deaths', hue='gender')
plt.title('COVID-19 cases by age and gender in Heidelberg, Germany')
sns.despine()
plt.show()
